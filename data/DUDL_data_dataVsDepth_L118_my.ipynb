# %% [markdown]
# |<h2>Course:</h2>|<h1><a href="https://udemy.com/course/deeplearning_x/?couponCode=202508" target="_blank">A deep understanding of deep learning</a></h1>|
# |-|:-:|
# |<h2>Section:</h2>|<h1>More on data<h1>|
# |<h2>Lecture:</h2>|<h1><b>Sample size and network depth<b></h1>|
#
# <br>
#
# <h5><b>Teacher:</b> Mike X Cohen, <a href="https://sincxpress.com" target="_blank">sincxpress.com</a></h5>
# <h5><b>Course URL:</b> <a href="https://udemy.com/course/deeplearning_x/?couponCode=202508" target="_blank">udemy.com/course/deeplearning_x/?couponCode=202508</a></h5>
# <i>Using the code without the course may lead to confusion or errors.</i>

# %%
# import libraries
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader,TensorDataset
from sklearn.model_selection import train_test_split

import numpy as np

import matplotlib.pyplot as plt
import matplotlib_inline.backend_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

# %%
# a function that creates data

def createSomeData(nPerClust):

  A = [ 1, 1 ]
  B = [ 5, 1 ]
  C = [ 4, 4 ]

  # generate data
  a = [ A[0]+np.random.randn(nPerClust) , A[1]+np.random.randn(nPerClust) ]
  b = [ B[0]+np.random.randn(nPerClust) , B[1]+np.random.randn(nPerClust) ]
  c = [ C[0]+np.random.randn(nPerClust) , C[1]+np.random.randn(nPerClust) ]

  # true labels
  labels_np = np.hstack(( np.zeros((nPerClust)),
                          np.ones( (nPerClust)),
                        1+np.ones( (nPerClust))  ))

  # concatanate into a matrix, then convert to a pytorch tensor
  data_np = np.hstack((a,b,c)).T

  # NEW: put all outputs into a dictionary
  output = {}
  output['data'] = torch.tensor(data_np).float()
  output['labels'] = torch.tensor(labels_np).long() # note: "long" format (integers) for labels

  # use scikitlearn to split the data
  train_data,test_data, train_labels,test_labels = train_test_split(output['data'], output['labels'], train_size=.9)

  # then convert them into PyTorch Datasets (note: already converted to tensors)
  train_data = TensorDataset(train_data,train_labels)
  test_data  = TensorDataset(test_data,test_labels)

  # finally, translate into dataloader objects
  batchsize  = 8
  output['train_data'] = DataLoader(train_data,batch_size=batchsize,shuffle=True,drop_last=True)
  output['test_data']  = DataLoader(test_data,batch_size=test_data.tensors[0].shape[0])

  return output

# %%
# Check that the function works

theData = createSomeData(50)

data = theData['data']
labels = theData['labels']

# show the data
fig = plt.figure(figsize=(5,5))
plt.plot(data[np.where(labels==0)[0],0],data[np.where(labels==0)[0],1],'bs',alpha=.5)
plt.plot(data[np.where(labels==1)[0],0],data[np.where(labels==1)[0],1],'ko',alpha=.5)
plt.plot(data[np.where(labels==2)[0],0],data[np.where(labels==2)[0],1],'r^',alpha=.5)
plt.title('The qwerties!')
plt.xlabel('qwerty dimension 1')
plt.ylabel('qwerty dimension 2')
plt.show()

# %% [markdown]
# # Create the model

# %%
# create a class for the model
from xml.parsers.expat import model


def createTheQwertyNet(nUnits,nLayers):

  class qwertyNet(nn.Module):
    def __init__(self,nUnits,nLayers):
      super().__init__()

      # create dictionary to store the layers
      self.layers = nn.ModuleDict()
      self.nLayers = nLayers

      ### input layer
      self.layers['input'] = nn.Linear(2,nUnits)

      ### hidden layers
      for i in range(1,nLayers):
        self.layers[f'hidden{i}'] = nn.Linear(nUnits,nUnits)

      ### output layer
      self.layers['output'] = nn.Linear(nUnits,3)


    # forward pass
    def forward(self,x):
      # input layer
      x = F.relu( self.layers['input'](x) )

      # hidden layers
      for i in range(1,self.nLayers):
        x = F.relu( self.layers[f'hidden{i}'](x) )

      # return output layer
      x = self.layers['output'](x)
      return x
    
    def count_units(self):
      total_units = 0
      for layer in self.modules():
        if isinstance(layer, torch.nn.modules.linear.Linear):
          total_units += layer.in_features
      return total_units

  # create the model instance
  net = qwertyNet(nUnits,nLayers)

  # loss function
  lossfun = nn.CrossEntropyLoss()

  # optimizer
  optimizer = torch.optim.Adam(net.parameters(),lr=1e-4)

  return net,lossfun,optimizer

# %%
# test the model with fake input

nUnitsPerLayer = 12
nLayers = 4

net,lossf,opt = createTheQwertyNet(nUnitsPerLayer,nLayers)
print(net)
print(f'The model has {net.count_units()} units')

# input is ten samples
input = torch.rand(10,2)
net(input)
# Out:
# qwertyNet(
#   (layers): ModuleDict(
#     (input): Linear(in_features=2, out_features=12, bias=True)
#     (hidden1): Linear(in_features=12, out_features=12, bias=True)
#     (hidden2): Linear(in_features=12, out_features=12, bias=True)
#     (hidden3): Linear(in_features=12, out_features=12, bias=True)
#     (output): Linear(in_features=12, out_features=3, bias=True)
#   )
# )
# The model has 50 units
# tensor([[ 0.0168,  0.3383, -0.3396],
#         [ 0.0148,  0.3396, -0.3419],
#         [ 0.0185,  0.3367, -0.3381],
#         [ 0.0174,  0.3372, -0.3400],
#         [ 0.0172,  0.3380, -0.3393],
#         [ 0.0163,  0.3385, -0.3401],
#         [ 0.0172,  0.3374, -0.3396],
#         [ 0.0163,  0.3389, -0.3428],
#         [ 0.0168,  0.3386, -0.3397],
#         [ 0.0168,  0.3377, -0.3402]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# # Note:
# ### There was a bug in the code I used in the video, which a student caught (see Q&A for this lecture).
# ### This file is corrected, but it doesn't change the pattern or conclusion of the video.
# ### The code cell below confirms that the model preserves the number of total units while varying the number of layers.

# %%
# a function to count the number of units
nNodesInModel = 80
layersRange   = [ 1,5,10,20 ]

# print out the model architectures
for lidx,layers in enumerate(layersRange):

  # create a model
  unitsperlayer = int(nNodesInModel//layersRange[lidx])
  net = createTheQwertyNet(unitsperlayer,layers)[0]

  # count and print the results
  print(f'Units/layer: {unitsperlayer}, layers: {layers}, Total count: {net.count_units()}')
# Out:
# Units/layer: 80, layers: 1, Total count: 82
# Units/layer: 16, layers: 5, Total count: 82
# Units/layer: 8, layers: 10, Total count: 82
# Units/layer: 4, layers: 20, Total count: 82

# %% [markdown]
# # A function that trains the model

# %%
def function2trainTheModel(nUnits,nLayers):

  # number of epochs
  numepochs = 50  # default 50

  # create a new model
  net,lossfun,optimizer = createTheQwertyNet(nUnits,nLayers)

  # initialize losses
  losses   = torch.zeros(numepochs)
  trainAcc = []
  testAcc  = []

  # loop over epochs
  for epochi in range(numepochs):
    
    net.train()  # put the network into "train" mode

    # loop over training data batches
    batchAcc  = []
    batchLoss = []
    for X,y in train_data:

      # forward pass and loss
      yHat = net(X)
      loss = lossfun(yHat,y)

      # backprop
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

      # loss from this batch
      batchLoss.append(loss.item())

      # compute accuracy
      matches = torch.argmax(yHat,axis=1) == y     # booleans (false/true)
      matchesNumeric = matches.float()             # convert to numbers (0/1)
      accuracyPct = 100*torch.mean(matchesNumeric) # average and x100
      batchAcc.append( accuracyPct )               # add to list of accuracies
    # end of batch loop...

    # now that we've trained through the batches, get their average training accuracy
    trainAcc.append( np.mean(batchAcc) )

    # and get average losses across the batches
    losses[epochi] = np.mean(batchLoss)

    # test accuracy
    X,y = next(iter(test_data)) # extract X,y from test dataloader
    net.eval() # put the network into "eval" mode
    with torch.no_grad(): # deactivates autograd
      yHat = net(X)
      # compare the following really long line of code to the training accuracy lines
      testAcc.append( 100*torch.mean((torch.argmax(yHat,axis=1)==y).float()) )

  # end epochs

  # function output
  return trainAcc,testAcc,losses,net

# %%
### Test the model once with a bit of data, just to make sure the code works.

# generate the data
theData = createSomeData(200)
train_data = theData['train_data']
test_data  = theData['test_data']

# run the model
trainAcc,testAcc,losses,net = function2trainTheModel(80,1)
print(f'Final test accuracy: {np.mean(testAcc[-10:]):.2f}%')


# show the results!
fig,ax = plt.subplots(1,2,figsize=(13,4))

ax[0].plot(losses.detach())
ax[0].set_ylabel('Loss')
ax[0].set_xlabel('epoch')
ax[0].set_title('Losses')

ax[1].plot(trainAcc,label='Train')
ax[1].plot(testAcc,label='Test')
ax[1].set_ylabel('Accuracy (%)')
ax[1].set_xlabel('Epoch')
ax[1].set_title(f'Accuracy (Final Test avg 10 epochs: {np.mean(testAcc[-10:]):.2f}%)')
ax[1].legend()
plt.show()
# Out:
# Final test accuracy: 90.33%

# %% [markdown]
# # Now for the experiment!

# %%
# before the experiment, configure and confirm the metaparameters

# specify the parameters for the model
nNodesInModel = 80
layersRange   = [ 1,5,10,20 ]
nDatapoints   = np.arange(50,551,50)

# create a legend for later plotting
legend = []

# print out the model architectures
for lidx,layers in enumerate(layersRange):

  # create a model
  unitsperlayer = int(nNodesInModel/layersRange[lidx])
  net = createTheQwertyNet(unitsperlayer,layers)[0]

  legend.append( '%s layers, %s units, %s params' %(layers,unitsperlayer,net.count_units()) )
  print('This model will have %s layers, each with %s units, totalling %s parameters' %(layers,unitsperlayer,net.count_units()))
# Out:
# This model will have 1 layers, each with 80 units, totalling 82 parameters
# This model will have 5 layers, each with 16 units, totalling 82 parameters
# This model will have 10 layers, each with 8 units, totalling 82 parameters
# This model will have 20 layers, each with 4 units, totalling 82 parameters

# %%
# note: takes ~5 mins
import time

# initialize results matrix
results = np.zeros((len(nDatapoints),len(layersRange),2))

for didx,pnts in enumerate(nDatapoints):

  # create data (note: same data for each layer manipulation!)
  theData = createSomeData(pnts)
  train_data = theData['train_data']
  test_data  = theData['test_data']


  # now loop over layers
  for lidx,layers in enumerate(layersRange):
    start_time = time.time()

    unitsperlayer = int(nNodesInModel/layersRange[lidx])
    trainAcc,testAcc,losses,net = function2trainTheModel(unitsperlayer,layers)

    # average of last 5 accuracies and losses
    results[didx,lidx,0] = np.mean( testAcc[-5:] )
    results[didx,lidx,1] = torch.mean(losses[-5:]).item()
    elapsed_time = time.time() - start_time
    print(f'Training time for {layers} layers and {unitsperlayer} units: {elapsed_time:.2f} seconds')
# Out:
# Training time for 1 layers and 80 units: 0.45 seconds
# Training time for 5 layers and 16 units: 0.79 seconds
# Training time for 10 layers and 8 units: 1.03 seconds
# Training time for 20 layers and 4 units: 1.67 seconds
# Training time for 1 layers and 80 units: 0.89 seconds
# Training time for 5 layers and 16 units: 1.45 seconds
# Training time for 10 layers and 8 units: 2.10 seconds
# Training time for 20 layers and 4 units: 3.46 seconds
# Training time for 1 layers and 80 units: 1.42 seconds
# Training time for 5 layers and 16 units: 2.22 seconds
# Training time for 10 layers and 8 units: 3.29 seconds
# Training time for 20 layers and 4 units: 5.55 seconds
# Training time for 1 layers and 80 units: 1.80 seconds
# Training time for 5 layers and 16 units: 3.14 seconds
# Training time for 10 layers and 8 units: 4.22 seconds
# Training time for 20 layers and 4 units: 7.18 seconds
# Training time for 1 layers and 80 units: 2.68 seconds
# Training time for 5 layers and 16 units: 3.73 seconds
# Training time for 10 layers and 8 units: 5.91 seconds
# Training time for 20 layers and 4 units: 10.60 seconds
# Training time for 1 layers and 80 units: 2.68 seconds
# Training time for 5 layers and 16 units: 4.90 seconds
# Training time for 10 layers and 8 units: 6.36 seconds
# Training time for 20 layers and 4 units: 10.58 seconds
# Training time for 1 layers and 80 units: 3.17 seconds
# Training time for 5 layers and 16 units: 5.12 seconds
# Training time for 10 layers and 8 units: 7.55 seconds
# Training time for 20 layers and 4 units: 13.11 seconds
# Training time for 1 layers and 80 units: 3.74 seconds
# Training time for 5 layers and 16 units: 6.38 seconds
# Training time for 10 layers and 8 units: 8.71 seconds
# Training time for 20 layers and 4 units: 15.84 seconds
# Training time for 1 layers and 80 units: 4.20 seconds
# Training time for 5 layers and 16 units: 6.84 seconds
# Training time for 10 layers and 8 units: 9.75 seconds
# Training time for 20 layers and 4 units: 17.59 seconds
# Training time for 1 layers and 80 units: 4.62 seconds
# Training time for 5 layers and 16 units: 8.89 seconds
# Training time for 10 layers and 8 units: 11.84 seconds
# Training time for 20 layers and 4 units: 19.97 seconds
# Training time for 1 layers and 80 units: 5.93 seconds
# Training time for 5 layers and 16 units: 8.45 seconds
# Training time for 10 layers and 8 units: 11.53 seconds
# Training time for 20 layers and 4 units: 20.95 seconds

# %%
# show the results!

fig,ax = plt.subplots(1,2,figsize=(15,5))
ax[0].plot(nDatapoints,results[:,:,1],'s-')
ax[0].set_ylabel('Loss')
ax[0].set_xlabel('Number of data points')
ax[0].legend(legend)
ax[0].set_title('Losses')

ax[1].plot(nDatapoints,results[:,:,0],'o-')
ax[1].set_ylabel('Accuracy (%)')
ax[1].set_xlabel('Number of data points')
ax[1].set_title('Accuracy')
ax[1].legend(legend)
plt.show()

# %%
# Interpretation:
#   Learning depends more on the architecture and the nature of the problem, than on the number of parameters.

# %% [markdown]
# # Additional explorations

# %%
# 1) The model learns faster and better with the Adam optimizer. In fact, I intentionally used SGD here to make the
#    model worse for this demonstration! Change the optimizer to Adam. What do you think is a good learning rate?
#    More importantly: Do the conclusions of this experiment hold for the Adam optimizer?
# Answer: I see 1e-4 is a good learning rate.
#
# 2) Add a timer to the experiment loop. Does the training duration relate to the number of layers or the number
#    of parameters?
# Answer: Number of layers seems to have a bigger impact on training time than number of parameters. In general network seems to learn longer wit hinceasingn number
# of layers. Also the data/problem itsel has an impact on training time.
#
# 3) Do the two deepest models eventually learn if you increase the number of training epochs? (Note: because this
#    question is only about the deepest models and because training time will increase, you need only test the two
#    models, not all four.)
# Answer: At some time point deepest models also learn, but need more epochs and data.
#
